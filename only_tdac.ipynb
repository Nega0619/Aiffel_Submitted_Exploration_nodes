# %% [markdown]
# <a href="https://colab.research.google.com/github/Nega0619/Aiffel_Submitted_Exploration_nodes/blob/main/only_tdac.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/agileSoda/
# Out:
# /content/drive/MyDrive/agileSoda

# %%
# ! pip install -r requirements.txt

# %%
# Policy

from string import ascii_uppercase
# from draw_utils import *
# from pyglet.gl import *
import numpy as np
import pandas as pd
import os


# reward
move_reward = -1
obs_reward = -100
goal_reward = 1000
print('reward:' , move_reward, obs_reward, goal_reward)

__file__ = '/content/drive/MyDrive/agileSoda/'
local_path = os.path.abspath(os.path.join(os.path.dirname(__file__)))


class Simulator:
    def __init__(self):
        '''
        height : 그리드 높이
        width : 그리드 너비 
        inds : A ~ Q alphabet list
        '''
        # Load train data
        self.files = pd.read_csv(os.path.join(local_path, "./data/factory_order_train.csv"))
        self.height = 10
        self.width = 9
        self.inds = list(ascii_uppercase)[:17]

    def set_box(self):
        '''
        아이템들이 있을 위치를 미리 정해놓고 그 위치 좌표들에 아이템이 들어올 수 있으므로 그리드에 100으로 표시한다.
        데이터 파일에서 이번 에피소드 아이템 정보를 받아 가져와야 할 아이템이 있는 좌표만 -100으로 표시한다.
        self.local_target에 에이전트가 이번에 방문해야할 좌표들을 저장한다.
        따라서 가져와야하는 아이템 좌표와 end point 좌표(처음 시작했던 좌표로 돌아와야하므로)가 들어가게 된다.
        '''
        box_data = pd.read_csv(os.path.join(local_path, "./data/box.csv"))

        # 물건이 들어있을 수 있는 경우
        for box in box_data.itertuples(index = True, name ='Pandas'):
            self.grid[getattr(box, "row")][getattr(box, "col")] = 100

        # 물건이 실제 들어있는 경우
        order_item = list(set(self.inds) & set(self.items))
        order_csv = box_data[box_data['item'].isin(order_item)]

        for order_box in order_csv.itertuples(index = True, name ='Pandas'):
            self.grid[getattr(order_box, "row")][getattr(order_box, "col")] = -100
            # local target에 가야 할 위치 좌표 넣기
            self.local_target.append(
                [getattr(order_box, "row"),
                 getattr(order_box, "col")]
                )
            
        # self.local_target.sort()
        self.local_target.append([9,4])

        # 알파벳을 Grid에 넣어서 -> grid에 2Dconv 적용 가능

    def set_obstacle(self):
        '''
        장애물이 있어야하는 위치는 미리 obstacles.csv에 정의되어 있다. 이 좌표들을 0으로 표시한다.
        '''
        obstacles_data = pd.read_csv(os.path.join(local_path, "./data/obstacles.csv"))
        for obstacle in obstacles_data.itertuples(index = True, name ='Pandas'):
            self.grid[getattr(obstacle, "row")][getattr(obstacle, "col")] = 0

    def reset(self, epi):
        '''
        reset()은 첫 스텝에서 사용되며 그리드에서 에이전트 위치가 start point에 있게 한다.

        :param epi: episode, 에피소드 마다 가져와야 할 아이템 리스트를 불러올 때 사용
        :return: 초기셋팅 된 그리드
        :rtype: numpy.ndarray
        _____________________________________________________________________________________
        items : 이번 에피소드에서 가져와야하는 아이템들
        terminal_location : 현재 에이전트가 찾아가야하는 목적지
        local_target : 한 에피소드에서 찾아가야하는 아이템 좌표, 마지막 엔드 포인트 등의 위치좌표들
        actions: visualization을 위해 에이전트 action을 저장하는 리스트
        curloc : 현재 위치
        '''

        # initial episode parameter setting
        self.epi = epi
        self.items = list(self.files.iloc[self.epi])[0]
        self.cumulative_reward = 0
        self.terminal_location = None
        self.local_target = []
        self.actions = []

        # initial grid setting
        self.grid = np.ones((self.height, self.width), dtype="float16")

        # set information about the gridworld
        self.set_box()
        self.set_obstacle()

        # start point를 grid에 표시
        self.curloc = [9, 4]
        self.grid[int(self.curloc[0])][int(self.curloc[1])] = -5
        
        self.done = False
        
        return self.local_target

    def apply_action(self, action, cur_x, cur_y):
        '''
        에이전트가 행한 action대로 현 에이전트의 위치좌표를 바꾼다.
        action은 discrete하며 4가지 up,down,left,right으로 정의된다.
        
        :param x: 에이전트의 현재 x 좌표
        :param y: 에이전트의 현재 y 좌표
        :return: action에 따라 변한 에이전트의 x 좌표, y 좌표
        :rtype: int, int
        '''
        new_x = cur_x
        new_y = cur_y
        # up
        if action == 0:
            new_x = cur_x - 1
            # print('위위 0: x-1')
        # down
        elif action == 1:
            new_x = cur_x + 1
            # print('아래 1 : x+1')
        # left
        elif action == 2:
            new_y = cur_y - 1
            # print('왼쪽 2 : y-1')
        # right
        elif action == 3:
            new_y = cur_y + 1
            # print('오른 3 : y+1')
        else :
            print('그런 행동은 없다.')

        return int(new_x), int(new_y)


    def get_reward(self, new_x, new_y, out_of_boundary):
        '''
        get_reward함수는 리워드를 계산하는 함수이며, 상황에 따라 에이전트가 action을 옳게 했는지 판단하는 지표가 된다.

        :param new_x: action에 따른 에이전트 새로운 위치좌표 x
        :param new_y: action에 따른 에이전트 새로운 위치좌표 y
        :param out_of_boundary: 에이전트 위치가 그리드 밖이 되지 않도록 제한
        :return: action에 따른 리워드
        :rtype: float
        '''

        # 바깥으로 나가는 경우
        if any(out_of_boundary):
            reward = obs_reward
        else:
            # 장애물에 부딪히는 경우 
            if self.grid[new_x][new_y] == 0:
                reward = obs_reward  

            # 현재 목표에 도달한 경우
            elif new_x == self.terminal_location[0] and new_y == self.terminal_location[1]:
                reward = goal_reward

            # 그냥 움직이는 경우 
            else:
                reward = move_reward

        return reward

    def step(self, action):
        ''' 
        에이전트의 action에 따라 step을 진행한다.
        action에 따라 에이전트 위치를 변환하고, action에 대해 리워드를 받고, 어느 상황에 에피소드가 종료되어야 하는지 등을 판단한다.
        에이전트가 endpoint에 도착하면 gif로 에피소드에서 에이전트의 행동이 저장된다.

        :param action: 에이전트 행동
        :return:
            grid, 그리드
            reward, 리워드
            cumulative_reward, 누적 리워드
            done, 종료 여부
            goal_ob_reward, goal까지 아이템을 모두 가지고 돌아오는 finish율 계산을 위한 파라미터

        :rtype: numpy.ndarray, float, float, bool, bool/str

        (Hint : 시작 위치 (9,4)에서 up말고 다른 action은 전부 장애물이므로 action을 고정하는 것이 좋음)
        '''

        self.terminal_location = self.local_target[0]
        cur_x,cur_y = self.curloc
        self.actions.append((cur_x, cur_y))

        goal_ob_reward = False
        
        new_x, new_y = self.apply_action(action, cur_x, cur_y)

        out_of_boundary = [new_x < 0, new_x >= self.height, new_y < 0, new_y >= self.width]

        # 바깥으로 나가는 경우 종료
        if any(out_of_boundary):
            self.done = True
            goal_ob_reward = False
            self.curloc = [new_x, new_y]
        else:
            # 장애물에 부딪히는 경우 종료
            if self.grid[new_x][new_y] == 0:
                self.done = True
                goal_ob_reward = False
                self.curloc = [new_x, new_y]

            # 현재 목표에 도달한 경우, 다음 목표설정
            elif new_x == self.terminal_location[0] and new_y == self.terminal_location[1]:

                # end point 일 때
                if [new_x, new_y] == [9,4]:
                    self.done = False

                self.local_target.remove(self.local_target[0])
                self.grid[cur_x][cur_y] = 1
                self.grid[new_x][new_y] = -5
                goal_ob_reward = True
                self.curloc = [new_x, new_y]
            else:
                # 그냥 움직이는 경우 
                self.grid[cur_x][cur_y] = 1
                self.grid[new_x][new_y] = -5
                self.curloc = [new_x,new_y]
                
        reward = self.get_reward(new_x, new_y, out_of_boundary)
        self.cumulative_reward += reward

#         print('현재는 gif가 만들어지지 않습니다.')
        # if self.done == True:
        #     if [new_x, new_y] == [9, 4]:
        #         if self.terminal_location == [9, 4]:
        #             # 완료되면 GIFS 저장
        #             goal_ob_reward = 'finish'
        #             height = 10
        #             width = 9
        #             display = Display(visible=False, size=(width, height))
        #             display.start()
        
        #             start_point = (9, 4)
        #             unit = 50
        #             screen_height = height * unit
        #             screen_width = width * unit
        #             log_path = "./logs"
        #             data_path = "./data"
        #             render_cls = Render(screen_width, screen_height, unit, start_point, data_path, log_path)
        #             for idx, new_pos in enumerate(self.actions):
        #                 render_cls.update_movement(new_pos, idx+1)
        
        #             render_cls.save_gif(self.epi, '_성공')
        #             render_cls.viewer.close()
        #             display.stop()
        # else:
        #     # 완료되면 GIFS 저장
        #             height = 10
        #             width = 9
        #             display = Display(visible=False, size=(width, height))
        #             display.start()
        
        #             start_point = (9, 4)
        #             unit = 50
        #             screen_height = height * unit
        #             screen_width = width * unit
        #             log_path = "./logs"
        #             data_path = "./data"
        #             render_cls = Render(screen_width, screen_height, unit, start_point, data_path, log_path)
        #             for idx, new_pos in enumerate(self.actions):
        #                 render_cls.update_movement(new_pos, idx+1)
        
        #             render_cls.save_gif(self.epi, '_실패')
        #             render_cls.viewer.close()
        #             display.stop()

        return self.get_current_state(), reward, self.cumulative_reward, self.done, goal_ob_reward

    def get_current_state(self):
        state = (self.curloc[0], self.curloc[1], self.local_target[0][0], self.local_target[0][1])
        return np.array(state)

    def get_grid(self):
        # print(self.grid)
        return self.grid


# if __name__ == "__main__":

#     sim = Simulator()
#     files = pd.read_csv("./data/factory_order_train.csv")
   
#     for epi in range(2): # len(files)):
#         items = list(files.iloc[epi])[0]
#         done = False
#         i = 0
#         obs = sim.reset(epi)
#         actions = [0, 0, 2, 2, 2, 0, 0, 0, 0, 0, 0, 0, 3, 3, 3, 3, 3, 3, 1, 1, 1, 1, 1, 1, 1, 2, 2, 2, 1]

#         while done == False:
            
#             i += 1
#             next_obs, reward, cumul ,done, goal_reward = sim.step(actions[i])

#             obs = next_obs

#             if (done == True) or (i == (len(actions)-1)):
#                 i =0
# Out:
# reward: -1 -100 1000

# %%
# policy.py

import gym
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Categorical

#Hyperparameters
learning_rate = 0.0002
gamma         = 0.98

class TD_ActorCritic(nn.Module):
    def __init__(self):
        super(TD_ActorCritic, self).__init__()
        self.data = []
        
        self.fc1 = nn.Linear(4,256) # 공유되는 layer 
        self.fc_pi = nn.Linear(256, 4)
        self.fc_v = nn.Linear(256,1)
        self.optimizer = optim.Adam(self.parameters(), lr=learning_rate)
      
    # 두개의 NN
    def pi(self, x, softmax_dim = 0): # pi NN
        x = F.relu(self.fc1(x))
        x = self.fc_pi(x)
        prob = F.softmax(x, dim=softmax_dim) # softmax
        return prob
    
    def v(self, x): # value NN
        x = F.relu(self.fc1(x))
        v = self.fc_v(x) # value는 확률이 아니므로 softmax 불필요 
        return v
    
    def put_data(self, transition):
        self.data.append(transition)
        
    # 모은 데이터로 batch를 생성
    def make_batch(self):
        s_lst, a_lst, r_lst, s_prime_lst, done_lst = [], [], [], [], []
        for transition in self.data: 
            s,a,r,s_prime,done = transition
            s_lst.append(s)
            a_lst.append([a])
            r_lst.append([r/100.0])
            s_prime_lst.append(s_prime)
            done_mask = 0.0 if done else 1.0
            done_lst.append([done_mask])

        # 같은 속성끼리 모아서 tensor로 전환
        s_batch, a_batch, r_batch, s_prime_batch, done_batch = torch.tensor(s_lst, dtype=torch.float), torch.tensor(a_lst), \
                                                               torch.tensor(r_lst, dtype=torch.float), torch.tensor(s_prime_lst, dtype=torch.float), \
                                                               torch.tensor(done_lst, dtype=torch.float)
        self.data = []
        return s_batch, a_batch, r_batch, s_prime_batch, done_batch
    # 학습 함수
    def train_net(self):
        s, a, r, s_prime, done = self.make_batch() # make_batch로 들어왔던 데이터 이용해서 tensor 생성됨 
        td_target = r + gamma * self.v(s_prime) * done # td_target: 정답
        delta = td_target - self.v(s) # target - v(s)
        
        pi = self.pi(s, softmax_dim=1) # pi action 확률들
        pi_a = pi.gather(1,a) # 거기서 고른 action
        loss = -torch.log(pi_a) * delta.detach() + F.smooth_l1_loss(self.v(s), td_target.detach())
              #policy_loss                         # value_loss
        
        # delta는 상수값이므로 detach() gradient가 생성되지 않게함
        self.optimizer.zero_grad()
        loss.mean().backward()
        self.optimizer.step()

# %%
import pandas as pd
import torch

n_rollout=10

# main
# if __name__ == "__main__":

files = pd.read_csv('./data/factory_order_train.csv')
episodes = len(files)

sim = Simulator()
model = TD_ActorCritic()

max_cum_reward = -99999

########################################################
# 액션 저장하는 txt파일 만들기
actions_file_name='only_tdac_'+str(move_reward)+'_'+str(obs_reward)+'_'+str(goal_reward)+'.txt'
f = open(actions_file_name, 'w')
########################################################

for epi in range(episodes):
  sim.reset(epi)
  state = sim.get_current_state()
  print('\n\n▶▶▶{}번째 에피소드 시작, env 초기화 완료.'.format(epi))

  # 아이템 리스트 확인
  items = list(files.iloc[epi])[0]
  print('가져와야 할 아이템 : ' + list(files.iloc[epi])[0] + '\n')
  
  done = False

  while done == False:
    for t in range(n_rollout):
      prob = model.pi(torch.from_numpy(state).float())
      m = Categorical(prob)
      action = m.sample().item()

      state_prime, reward, cumul ,done, goal_ob_reward = sim.step(action)
      print('결과로 나온 데이터 :', state_prime, reward, cumul ,done, goal_ob_reward)
      # s_prime, r, done, info = env.step(a) # 그 action을 env로 보내서 다음 s, a, r 추출
      model.put_data((state, action, reward, state_prime, done)) # s, a, r, s' 데이터 수집
      print('학습중인 데이터    :',state, action, reward, state_prime, done)

      state = state_prime

      if done:
        break
    model.train_net()
  
  max_cum_reward = max_cum_reward if max_cum_reward > cumul else cumul
  print(epi, 'max cum reward', max_cum_reward)

#########################################    
  if len(sim.actions) > 5:
      f.write(str(epi)+'/'+str(items)+'/'+str(cumul)+'\n')
      f.write(str(sim.actions))
      f.write('\n')

f.close()
#########################################
# Out:
# ▶▶▶0번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['H', 'L', 'M']
#
# 결과로 나온 데이터 : [8 4 0 3] -1 -1 False False
# 학습중인 데이터    : [9 4 0 3] 0 -1 [8 4 0 3] False
# 결과로 나온 데이터 : [7 4 0 3] -1 -2 False False
# 학습중인 데이터    : [8 4 0 3] 0 -1 [7 4 0 3] False
# 결과로 나온 데이터 : [7 5 0 3] -1 -3 False False
# 학습중인 데이터    : [7 4 0 3] 3 -1 [7 5 0 3] False
# 결과로 나온 데이터 : [7 4 0 3] -1 -4 False False
# 학습중인 데이터    : [7 5 0 3] 2 -1 [7 4 0 3] False
# 결과로 나온 데이터 : [6 4 0 3] -100 -104 True False
# 학습중인 데이터    : [7 4 0 3] 0 -100 [6 4 0 3] True
# 0 max cum reward -104
#
#
# ▶▶▶1번째 에피소드 시작, env 초기화 완료.
# 가져와야 할 아이템 : ['F', 'M', 'O', 'P', 'Q']
#
# 결과로 나온 데이터 : [8 4 0 1] -1 -1 False False
# 학습중인 데이터    : [9 4 0 1] 0
# /content/drive/MyDrive/agileSoda/:52: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:210.)
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 결과로 나온 데이터 : [0 4 2 8] -1 -42699 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 3 2 8] -1 -42700 False False
# 학습중인 데이터    : [0 4 2 8] 2 -1 [0 3 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42701 False False
# 학습중인 데이터    : [0 3 2 8] 3 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 3 2 8] -1 -42702 False False
# 학습중인 데이터    : [0 4 2 8] 2 -1 [0 3 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42703 False False
# 학습중인 데이터    : [0 3 2 8] 3 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 3 2 8] -1 -42704 False False
# 학습중인 데이터    : [0 4 2 8] 2 -1 [0 3 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42705 False False
# 학습중인 데이터    : [0 3 2 8] 3 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42706 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42707 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42708 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42709 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42710 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42711 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42712 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42713 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42714 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42715 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42716 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42717 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42718 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42719 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42720 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42721 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 3 2 8] -1 -42722 False False
# 학습중인 데이터    : [0 4 2 8] 2 -1 [0 3 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42723 False False
# 학습중인 데이터    : [0 3 2 8] 3 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42724 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42725 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42726 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42727 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42728 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42729 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42730 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42731 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42732 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42733 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42734 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42735 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 3 2 8] -1 -42736 False False
# 학습중인 데이터    : [0 4 2 8] 2 -1 [0 3 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42737 False False
# 학습중인 데이터    : [0 3 2 8] 3 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42738 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42739 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42740 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42741 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42742 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42743 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42744 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42745 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 7 2 8] -1 -42746 False False
# 학습중인 데이터    : [0 6 2 8] 3 -1 [0 7 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42747 False False
# 학습중인 데이터    : [0 7 2 8] 2 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42748 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42749 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42750 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42751 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 3 2 8] -1 -42752 False False
# 학습중인 데이터    : [0 4 2 8] 2 -1 [0 3 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42753 False False
# 학습중인 데이터    : [0 3 2 8] 3 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42754 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42755 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42756 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42757 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42758 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42759 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42760 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42761 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42762 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42763 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42764 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42765 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42766 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42767 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42768 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42769 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42770 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42771 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42772 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42773 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42774 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42775 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42776 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42777 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42778 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42779 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42780 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42781 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42782 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42783 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42784 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42785 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 3 2 8] -1 -42786 False False
# 학습중인 데이터    : [0 4 2 8] 2 -1 [0 3 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42787 False False
# 학습중인 데이터    : [0 3 2 8] 3 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42788 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42789 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42790 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42791 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42792 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42793 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42794 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42795 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42796 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42797 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42798 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42799 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 3 2 8] -1 -42800 False False
# 학습중인 데이터    : [0 4 2 8] 2 -1 [0 3 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42801 False False
# 학습중인 데이터    : [0 3 2 8] 3 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42802 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42803 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42804 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42805 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42806 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42807 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42808 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42809 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42810 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42811 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42812 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42813 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 7 2 8] -1 -42814 False False
# 학습중인 데이터    : [0 6 2 8] 3 -1 [0 7 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42815 False False
# 학습중인 데이터    : [0 7 2 8] 2 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42816 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42817 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 7 2 8] -1 -42818 False False
# 학습중인 데이터    : [0 6 2 8] 3 -1 [0 7 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42819 False False
# 학습중인 데이터    : [0 7 2 8] 2 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42820 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42821 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 7 2 8] -1 -42822 False False
# 학습중인 데이터    : [0 6 2 8] 3 -1 [0 7 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42823 False False
# 학습중인 데이터    : [0 7 2 8] 2 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42824 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42825 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42826 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42827 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42828 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42829 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42830 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42831 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42832 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42833 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42834 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42835 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42836 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42837 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42838 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42839 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 3 2 8] -1 -42840 False False
# 학습중인 데이터    : [0 4 2 8] 2 -1 [0 3 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42841 False False
# 학습중인 데이터    : [0 3 2 8] 3 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42842 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42843 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42844 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42845 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42846 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42847 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42848 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42849 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42850 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42851 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42852 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42853 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 3 2 8] -1 -42854 False False
# 학습중인 데이터    : [0 4 2 8] 2 -1 [0 3 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42855 False False
# 학습중인 데이터    : [0 3 2 8] 3 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42856 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42857 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42858 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42859 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42860 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42861 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42862 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42863 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42864 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42865 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42866 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42867 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42868 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42869 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42870 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42871 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42872 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42873 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42874 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42875 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 3 2 8] -1 -42876 False False
# 학습중인 데이터    : [0 4 2 8] 2 -1 [0 3 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42877 False False
# 학습중인 데이터    : [0 3 2 8] 3 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42878 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42879 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42880 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42881 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42882 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42883 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42884 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42885 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42886 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42887 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42888 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42889 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42890 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42891 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 3 2 8] -1 -42892 False False
# 학습중인 데이터    : [0 4 2 8] 2 -1 [0 3 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42893 False False
# 학습중인 데이터    : [0 3 2 8] 3 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 3 2 8] -1 -42894 False False
# 학습중인 데이터    : [0 4 2 8] 2 -1 [0 3 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42895 False False
# 학습중인 데이터    : [0 3 2 8] 3 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42896 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42897 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42898 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42899 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42900 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42901 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42902 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42903 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42904 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42905 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42906 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42907 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42908 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42909 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42910 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42911 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42912 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42913 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42914 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42915 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42916 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42917 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42918 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42919 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42920 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42921 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42922 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42923 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42924 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42925 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42926 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42927 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42928 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42929 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42930 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42931 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42932 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42933 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42934 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42935 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 7 2 8] -1 -42936 False False
# 학습중인 데이터    : [0 6 2 8] 3 -1 [0 7 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42937 False False
# 학습중인 데이터    : [0 7 2 8] 2 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42938 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42939 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42940 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42941 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42942 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42943 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42944 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42945 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42946 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42947 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42948 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42949 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42950 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42951 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42952 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42953 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42954 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42955 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42956 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42957 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 7 2 8] -1 -42958 False False
# 학습중인 데이터    : [0 6 2 8] 3 -1 [0 7 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42959 False False
# 학습중인 데이터    : [0 7 2 8] 2 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42960 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42961 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42962 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42963 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42964 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42965 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42966 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42967 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42968 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42969 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42970 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42971 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42972 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42973 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42974 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42975 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42976 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42977 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42978 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42979 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42980 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42981 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42982 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42983 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42984 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42985 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 7 2 8] -1 -42986 False False
# 학습중인 데이터    : [0 6 2 8] 3 -1 [0 7 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42987 False False
# 학습중인 데이터    : [0 7 2 8] 2 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42988 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42989 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42990 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42991 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42992 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42993 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42994 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -42995 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42996 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42997 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -42998 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -42999 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43000 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43001 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43002 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43003 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43004 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -43005 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43006 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43007 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43008 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43009 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43010 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43011 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43012 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -43013 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43014 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -43015 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43016 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -43017 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43018 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43019 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43020 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -43021 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43022 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43023 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43024 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43025 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43026 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -43027 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43028 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43029 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43030 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -43031 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43032 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43033 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43034 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43035 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43036 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -43037 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43038 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43039 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43040 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -43041 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43042 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43043 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43044 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -43045 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43046 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -43047 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 3 2 8] -1 -43048 False False
# 학습중인 데이터    : [0 4 2 8] 2 -1 [0 3 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -43049 False False
# 학습중인 데이터    : [0 3 2 8] 3 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43050 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -43051 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43052 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -43053 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43054 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43055 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43056 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -43057 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43058 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -43059 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43060 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -43061 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43062 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -43063 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43064 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -43065 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43066 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43067 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43068 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43069 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43070 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -43071 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 3 2 8] -1 -43072 False False
# 학습중인 데이터    : [0 4 2 8] 2 -1 [0 3 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -43073 False False
# 학습중인 데이터    : [0 3 2 8] 3 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 3 2 8] -1 -43074 False False
# 학습중인 데이터    : [0 4 2 8] 2 -1 [0 3 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -43075 False False
# 학습중인 데이터    : [0 3 2 8] 3 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43076 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43077 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43078 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43079 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43080 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43081 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43082 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -43083 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43084 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43085 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43086 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -43087 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43088 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -43089 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43090 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -43091 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43092 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43093 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43094 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43095 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43096 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43097 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43098 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43099 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43100 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43101 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43102 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -43103 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43104 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -43105 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43106 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43107 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43108 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43109 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43110 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43111 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43112 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -43113 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43114 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43115 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43116 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43117 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43118 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43119 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43120 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -43121 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43122 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43123 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43124 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -43125 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 3 2 8] -1 -43126 False False
# 학습중인 데이터    : [0 4 2 8] 2 -1 [0 3 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -43127 False False
# 학습중인 데이터    : [0 3 2 8] 3 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43128 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43129 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43130 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43131 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43132 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -43133 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43134 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -43135 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43136 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43137 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43138 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -43139 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43140 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43141 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43142 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43143 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43144 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -43145 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43146 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43147 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43148 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43149 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43150 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -43151 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43152 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43153 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 7 2 8] -1 -43154 False False
# 학습중인 데이터    : [0 6 2 8] 3 -1 [0 7 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43155 False False
# 학습중인 데이터    : [0 7 2 8] 2 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43156 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43157 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43158 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43159 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43160 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -43161 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43162 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43163 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43164 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43165 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43166 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -43167 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43168 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43169 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 7 2 8] -1 -43170 False False
# 학습중인 데이터    : [0 6 2 8] 3 -1 [0 7 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43171 False False
# 학습중인 데이터    : [0 7 2 8] 2 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43172 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -43173 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43174 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -43175 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43176 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -43177 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43178 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -43179 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43180 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43181 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 7 2 8] -1 -43182 False False
# 학습중인 데이터    : [0 6 2 8] 3 -1 [0 7 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43183 False False
# 학습중인 데이터    : [0 7 2 8] 2 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43184 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -43185 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43186 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -43187 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43188 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43189 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43190 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43191 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43192 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43193 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43194 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43195 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 7 2 8] -1 -43196 False False
# 학습중인 데이터    : [0 6 2 8] 3 -1 [0 7 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43197 False False
# 학습중인 데이터    : [0 7 2 8] 2 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 7 2 8] -1 -43198 False False
# 학습중인 데이터    : [0 6 2 8] 3 -1 [0 7 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43199 False False
# 학습중인 데이터    : [0 7 2 8] 2 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43200 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -43201 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43202 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43203 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43204 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43205 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43206 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43207 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43208 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -43209 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43210 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -43211 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43212 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43213 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43214 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -43215 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43216 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43217 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43218 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -43219 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -43220 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# ...
# 학습중인 데이터    : [0 7 2 8] 2 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 7 2 8] -1 -45022 False False
# 학습중인 데이터    : [0 6 2 8] 3 -1 [0 7 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -45023 False False
# 학습중인 데이터    : [0 7 2 8] 2 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45024 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -45025 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45026 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -45027 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45028 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -45029 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45030 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -45031 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45032 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -45033 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45034 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -45035 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45036 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -45037 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45038 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -45039 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45040 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -45041 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45042 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -45043 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45044 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -45045 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45046 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -45047 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45048 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -45049 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45050 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -45051 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45052 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -45053 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45054 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -45055 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45056 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -45057 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45058 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -45059 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45060 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -45061 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45062 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -45063 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45064 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -45065 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45066 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -45067 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45068 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -45069 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45070 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -45071 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45072 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -45073 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45074 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -45075 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45076 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -45077 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45078 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -45079 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45080 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -45081 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45082 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -45083 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45084 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -45085 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45086 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -45087 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45088 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -45089 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45090 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -45091 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 3 2 8] -1 -45092 False False
# 학습중인 데이터    : [0 4 2 8] 2 -1 [0 3 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -45093 False False
# 학습중인 데이터    : [0 3 2 8] 3 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45094 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -45095 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45096 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -45097 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45098 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -45099 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45100 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -45101 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45102 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -45103 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45104 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -45105 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45106 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -45107 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45108 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -45109 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45110 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -45111 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45112 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -45113 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45114 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -45115 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45116 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -45117 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45118 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -45119 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45120 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -45121 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45122 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -45123 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45124 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -45125 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45126 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -45127 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45128 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -45129 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45130 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -45131 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45132 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -45133 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45134 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -45135 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45136 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -45137 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45138 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -45139 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45140 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -45141 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45142 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -45143 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45144 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -45145 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45146 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -45147 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45148 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -45149 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 3 2 8] -1 -45150 False False
# 학습중인 데이터    : [0 4 2 8] 2 -1 [0 3 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -45151 False False
# 학습중인 데이터    : [0 3 2 8] 3 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45152 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -45153 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45154 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -45155 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45156 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -45157 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45158 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -45159 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45160 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -45161 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45162 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -45163 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 3 2 8] -1 -45164 False False
# 학습중인 데이터    : [0 4 2 8] 2 -1 [0 3 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -45165 False False
# 학습중인 데이터    : [0 3 2 8] 3 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45166 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -45167 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45168 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -45169 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45170 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -45171 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45172 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -45173 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45174 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -45175 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45176 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -45177 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45178 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -45179 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45180 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -45181 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45182 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -45183 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45184 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -45185 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45186 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -45187 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45188 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -45189 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45190 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 4 2 8] -1 -45191 False False
# 학습중인 데이터    : [0 5 2 8] 2 -1 [0 4 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45192 False False
# 학습중인 데이터    : [0 4 2 8] 3 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -45193 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45194 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -45195 False False
# 학습중인 데이터    : [0 5 2 8] 3 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 7 2 8] -1 -45196 False False
# 학습중인 데이터    : [0 6 2 8] 3 -1 [0 7 2 8] False
# 결과로 나온 데이터 : [0 6 2 8] -1 -45197 False False
# 학습중인 데이터    : [0 7 2 8] 2 -1 [0 6 2 8] False
# 결과로 나온 데이터 : [0 5 2 8] -1 -45198 False False
# 학습중인 데이터    : [0 6 2 8] 2 -1 [0 5 2 8] False
