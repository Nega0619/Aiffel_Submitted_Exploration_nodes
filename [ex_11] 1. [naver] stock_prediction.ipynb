# %% [markdown]
# ![image.png](attachment:image.png)
#
# 오늘은 ARIMA를 통해 시계열 데이터를 에측하는 과정을 진행해보았습니다.
# 주제는 네이버에 대한 주식 시세 예측입니다. 2016-2019로 총 4년치의 데이터를 학습시켜보았습니다.

# %%
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error, mean_absolute_error

import math
import warnings
warnings.filterwarnings('ignore') #경고 무시

import os
import glob
from matplotlib.pylab import rcParams

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %% [markdown]
# # STEP 1 : 시계열 데이터 준비
# - 칼럼 종류: Date, Open, High, Low, Close, Adj Close, Volume
# - 날짜별로 시작가(Open), 최고가(High), 최저가(Low), 종가(Close), 수정종가(Adj Close), 거래량(Volume)이 저장되어 있는 것을 확인할 수 있습니다.
# - 우리는 종가(Close)만 사용하겠습니다. (주식 시장은 정해진 시간 동안만 거래가 가능합니다. 종가란 하루의 장이 마감하였을 때의 가격입니다.)
#
# ## 네이버 2016-2019 4년치

# %%
dataset_filepath = glob.glob('{}/aiffel/stock_prediction/data/*naver*.csv'.format(os.getenv('HOME')))
print(dataset_filepath)
df = pd.read_csv(dataset_filepath[0], index_col='date', parse_dates=True)

rcParams['figure.figsize'] = 13, 6  # matlab 차트의 기본 크기를 13, 6로 지정해 줍니다.


# del ts
ts = df['close']

print()
print(type(ts))

ts.head()
# Out:
# ['/aiffel/aiffel/stock_prediction/data/035420_naver.csv']
#
# <class 'pandas.core.series.Series'>
# date
# 2016-01-04    126400.0
# 2016-01-05    127400.0
# 2016-01-06    124600.0
# 2016-01-07    130400.0
# 2016-01-08    130400.0
# Name: close, dtype: float64

# %% [markdown]
# # step 2 : 각종 전처리 수행
#
# - 결측치 처리
# - 로그 변환
#
# ## 결측치 처리

# %%
ts = ts.interpolate(method='time')
ts[ts.isna()]  # Time Series에서 결측치가 있는 부분만 Series로 출력합니다.
# Out:
# Series([], Name: close, dtype: float64)

# %% [markdown]
# ## 로그변환

# %%
ts_log = np.log(ts)

# %% [markdown]
# # STEP 3 : 시계열 안정성 분석
#
# - 정성적 그래프 분석
# - 정량적 Augmented Dicky-Fuller Test
# - 시계열 분해(Time Series Decomposition)
# - Residual 안정성 확인

# %%
ts = df['close']
plt.plot(ts)

# %% [markdown]
# ## 정성적 그래프 분석

# %%
def plot_rolling_statistics(timeseries, window=12):
    
    rolmean = timeseries.rolling(window=window).mean()  # 이동평균 시계열
    rolstd = timeseries.rolling(window=window).std()    # 이동표준편차 시계열

     # 원본시계열, 이동평균, 이동표준편차를 plot으로 시각화해 본다.
    orig = plt.plot(timeseries, color='blue',label='Original')    
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label='Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)

# %%
def augmented_dickey_fuller_test(timeseries):
    # statsmodels 패키지에서 제공하는 adfuller 메서드를 호출합니다.
    dftest = adfuller(timeseries, autolag='AIC')  
    
    # adfuller 메서드가 리턴한 결과를 정리하여 출력합니다.
    print('Results of Dickey-Fuller Test:')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)' % key] = value
    print(dfoutput)

# %%
# 정성적 그래프 분석
plot_rolling_statistics(ts_log, window=12)

#정량적 Augmented Dicky-Fuller Test
augmented_dickey_fuller_test(ts_log)

#시계열 분해 (Time Series Decomposition)
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(ts_log, model='multiplicative', period = 30)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -1.872774
# p-value                          0.344975
# #Lags Used                       1.000000
# Number of Observations Used    974.000000
# Critical Value (1%)             -3.437082
# Critical Value (5%)             -2.864512
# Critical Value (10%)            -2.568352
# dtype: float64

# %% [markdown]
# # 결론 !¶
# p-value의 값 0.344975이므로, 0.05보다 매우 큰 값입니다. 분명히 귀무가설을 기각할 이유가 없습니다. 따라서 시계열은 실제로 비정상적입니다.

# %%
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

# %%
plt.subplot(411)
plt.plot(ts_log, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()

# %% [markdown]
# ## residual 안정성 확인

# %%
# 예시코드

residual.dropna(inplace=True)
augmented_dickey_fuller_test(residual)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -9.510256e+00
# p-value                        3.263866e-16
# #Lags Used                     1.800000e+01
# Number of Observations Used    9.270000e+02
# Critical Value (1%)           -3.437424e+00
# Critical Value (5%)           -2.864663e+00
# Critical Value (10%)          -2.568433e+00
# dtype: float64

# %% [markdown]
# # 결론 !¶
# p-value의 값 3.263866e-16 = 0.00000000000000032639이므로, 0.05보다 매우작은값입니다. 즉 p-value의 값이 유의 수준 0.05보다 매우 작으므로 귀무 가설을 기각하고 계열이 정상적이라고 간주할 수 있습니다.
#
# # 로그변환 만으론 부족, Moving average 제거

# %%
moving_avg = ts_log.rolling(window=12).mean()  # moving average구하기 
plt.plot(ts_log)
plt.plot(moving_avg, color='red')

# %%
ts_log_moving_avg = ts_log - moving_avg # 변화량 제거
ts_log_moving_avg.head(15)
# Out:
# date
# 2016-01-04         NaN
# 2016-01-05         NaN
# 2016-01-06         NaN
# 2016-01-07         NaN
# 2016-01-08         NaN
# 2016-01-11         NaN
# 2016-01-12         NaN
# 2016-01-13         NaN
# 2016-01-14         NaN
# 2016-01-15         NaN
# 2016-01-18         NaN
# 2016-01-19    0.030558
# 2016-01-20    0.017446
# 2016-01-21   -0.021193
# 2016-01-22    0.017379
# Name: close, dtype: float64

# %%
# 결측치 제거

ts_log_moving_avg.dropna(inplace=True)
ts_log_moving_avg.head(15)
# Out:
# date
# 2016-01-19    0.030558
# 2016-01-20    0.017446
# 2016-01-21   -0.021193
# 2016-01-22    0.017379
# 2016-01-25    0.022195
# 2016-01-26    0.029038
# 2016-01-27    0.014284
# 2016-01-28   -0.049168
# 2016-01-29   -0.051192
# 2016-02-01   -0.070355
# 2016-02-02   -0.082595
# 2016-02-03   -0.069785
# 2016-02-04   -0.059204
# 2016-02-05   -0.055615
# 2016-02-11   -0.107045
# Name: close, dtype: float64

# %%
plot_rolling_statistics(ts_log_moving_avg)

# %%
augmented_dickey_fuller_test(ts_log_moving_avg)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -9.236125e+00
# p-value                        1.628699e-15
# #Lags Used                     2.000000e+00
# Number of Observations Used    9.620000e+02
# Critical Value (1%)           -3.437166e+00
# Critical Value (5%)           -2.864549e+00
# Critical Value (10%)          -2.568372e+00
# dtype: float64

# %% [markdown]
# p-value의 값이  1.628699e-15 = 0.0000000000000016287로 유의미하게 작아졌습니다. 이제 시계열 값으로 사용이 가능할듯합니다!
#
# # STEP 4 : 학습, 테스트 데이터셋 생성

# %%
train_data, test_data = ts_log_moving_avg[:int(len(ts_log_moving_avg)*0.9)], ts_log_moving_avg[int(len(ts_log_moving_avg)*0.9):]
plt.figure(figsize=(10,6))
plt.grid(True)
plt.plot(ts_log_moving_avg, c='r', label='training dataset')  # train_data를 적용하면 그래프가 끊어져 보이므로 자연스러운 연출을 위해 ts_log_moving_avg를 선택
plt.plot(test_data, c='b', label='test dataset')
plt.legend()

# %% [markdown]
# # STEP 5 : 적정 ARIMA 모수 찾기
# - ACF, PACF 그려보기 -> p,q 구하기
# - 차분 안정성 확인 -> d 구하기
#
# ## ACF, PACF 그려보기 - p, q 구하기

# %%
plot_acf(ts_log_moving_avg)   # ACF : Autocorrelation 그래프 그리기
plot_pacf(ts_log_moving_avg)  # PACF : Partial Autocorrelation 그래프 그리기
plt.show()

# %% [markdown]
# ## 차분 안정성 확인 - d 구하기

# %%
# 1차 차분 구하기
diff_1 = ts_log.diff(periods=1).iloc[1:]
diff_1.plot(title='Difference 1st')

augmented_dickey_fuller_test(diff_1)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -33.985187
# p-value                          0.000000
# #Lags Used                       0.000000
# Number of Observations Used    974.000000
# Critical Value (1%)             -3.437082
# Critical Value (5%)             -2.864512
# Critical Value (10%)            -2.568352
# dtype: float64

# %%
# 혹시 필요한 경우 2차 차분 구하기
diff_2 = diff_1.diff(periods=1).iloc[1:]
diff_2.plot(title='Difference 2nd')

augmented_dickey_fuller_test(diff_2)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -1.378837e+01
# p-value                        9.022652e-26
# #Lags Used                     1.600000e+01
# Number of Observations Used    9.570000e+02
# Critical Value (1%)           -3.437202e+00
# Critical Value (5%)           -2.864565e+00
# Critical Value (10%)          -2.568381e+00
# dtype: float64

# %% [markdown]
# # STEP 6 : ARIMA 모델 훈련과 테스트 1
#
# ## (p, d, q) = 1, 0, 9
#
# - ARIMA 모델 빌드와 훈련
# - 모델 테스트 및 플로팅
# - 최종 예측 모델 정확도 측정(MAPE)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# p의 값을 1로 정해보았습니다. AR(1)일때 ACF는 계속 감소하고있고, PACF는 시차 2부터 0입니다.
#
# q의 값은 9로 정해보았습니다. ACF에서 0이 된 순간이고 PACF에서는 거의 값이 존재하지않듯 하기때문입니다.

# %% [markdown]
# d값은 1차 미분이나 2차미분이나 0의 안정화를 보였기 때문에 d=0을 시도해보았습니다.

# %%
# Build Model
model = ARIMA(train_data, order=(1, 0, 9))  # 1.65
fitted_m = model.fit() 

print(fitted_m.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  close   No. Observations:                  868
# Model:                 ARIMA(1, 0, 9)   Log Likelihood                2284.741
# Date:                Wed, 16 Feb 2022   AIC                          -4545.482
# Time:                        08:03:09   BIC                          -4488.288
# Sample:                             0   HQIC                         -4523.595
#                                 - 868
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0003      0.003      0.100      0.920      -0.006       0.007
# ar.L1          0.4397      0.274      1.607      0.108      -0.097       0.976
# ma.L1          0.4207      0.278      1.513      0.130      -0.124       0.966
# ma.L2          0.4242      0.237      1.789      0.074      -0.040       0.889
# ma.L3          0.3076      0.220      1.398      0.162      -0.124       0.739
# ma.L4          0.2699      0.180      1.499      0.134      -0.083       0.623
# ma.L5          0.2366      0.151      1.564      0.118      -0.060       0.533
# ma.L6          0.2011      0.126      1.593      0.111      -0.046       0.448
# ma.L7          0.1327      0.108      1.227      0.220      -0.079       0.345
# ma.L8          0.0990      0.080      1.241      0.215      -0.057       0.255
# ma.L9          0.0425      0.058      0.737      0.461      -0.071       0.156
# sigma2         0.0003   1.08e-05     28.061      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               146.93
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.13   Skew:                             0.28
# Prob(H) (two-sided):                  0.29   Kurtosis:                         4.94
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
fitted_m = fitted_m.predict()
fitted_m = fitted_m.drop(fitted_m.index[0])
plt.plot(fitted_m, label='predict')
plt.plot(train_data, label='train_data')
plt.legend()

# %%
model = ARIMA(train_data, order=(1, 0, 9))  # 1.65
fitted_m = model.fit() 
# Forecast : 결과가 fc에 담깁니다. 

fc = fitted_m.forecast(len(test_data), alpha=0.05)  # 95% conf
fc = np.array(fc)
# Make as pandas series
fc_series = pd.Series(fc, index=test_data.index)   # 예측결과

# Plot
plt.figure(figsize=(10,5), dpi=100)
plt.plot(train_data, label='training')
plt.plot(test_data, c='b', label='actual price')
plt.plot(fc_series, c='r',label='predicted price')
plt.legend()
plt.show()

# %%
mse = mean_squared_error(np.exp(test_data), np.exp(fc))
print('MSE: ', mse)

mae = mean_absolute_error(np.exp(test_data), np.exp(fc))
print('MAE: ', mae)

rmse = math.sqrt(mean_squared_error(np.exp(test_data), np.exp(fc)))
print('RMSE: ', rmse)

mape = np.mean(np.abs(np.exp(fc) - np.exp(test_data))/np.abs(np.exp(test_data)))
print('MAPE: {:.2f}%'.format(mape*100))
# Out:
# MSE:  0.0007472298064675291
# MAE:  0.02082326920355056
# RMSE:  0.027335504503621825
# MAPE: 2.02%

# %% [markdown]
# # 테스트 1 분석
#
# 보통 p + q < 2, p * q는 0인 값을 사용한다고 합니다. MAPE는 2.02로 나쁘진 않지만, 아무래도 q값이 컸던것 같아 위에서 많이쓰는 값에 최대한 맞춰보려합니다.

# %% [markdown]
# # STEP 6 : ARIMA 모델 훈련과 테스트 2
#
# ## (p, d, q) = 1, 0, 0
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# 테스트 1의 결론에 따라 p의 값은 1로주고, q의 값을 0으로 줘봤습니다.
#
# d = 0값을 주었습니다.

# %%
# Build Model
model = ARIMA(train_data, order=(1, 0, 0)) 
fitted_m = model.fit() 

print(fitted_m.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  close   No. Observations:                  868
# Model:                 ARIMA(1, 0, 0)   Log Likelihood                2276.409
# Date:                Wed, 16 Feb 2022   AIC                          -4546.818
# Time:                        08:03:20   BIC                          -4532.519
# Sample:                             0   HQIC                         -4541.346
#                                 - 868
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0006      0.004      0.155      0.877      -0.007       0.008
# ar.L1          0.8485      0.015     55.879      0.000       0.819       0.878
# sigma2         0.0003   1.07e-05     28.752      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.47   Jarque-Bera (JB):               145.75
# Prob(Q):                              0.49   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.13   Skew:                             0.28
# Prob(H) (two-sided):                  0.30   Kurtosis:                         4.93
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
fitted_m = fitted_m.predict()
fitted_m = fitted_m.drop(fitted_m.index[0])
plt.plot(fitted_m, label='predict')
plt.plot(train_data, label='train_data')
plt.legend()

# %%
model = ARIMA(train_data, order=(1, 0, 0))  # 1.65
fitted_m = model.fit() 
# Forecast : 결과가 fc에 담깁니다. 

fc = fitted_m.forecast(len(test_data), alpha=0.05)  # 95% conf
fc = np.array(fc)
# Make as pandas series
fc_series = pd.Series(fc, index=test_data.index)   # 예측결과

# Plot
plt.figure(figsize=(10,5), dpi=100)
plt.plot(train_data, label='training')
plt.plot(test_data, c='b', label='actual price')
plt.plot(fc_series, c='r',label='predicted price')
plt.legend()
plt.show()

# %%
mse = mean_squared_error(np.exp(test_data), np.exp(fc))
print('MSE: ', mse)

mae = mean_absolute_error(np.exp(test_data), np.exp(fc))
print('MAE: ', mae)

rmse = math.sqrt(mean_squared_error(np.exp(test_data), np.exp(fc)))
print('RMSE: ', rmse)

mape = np.mean(np.abs(np.exp(fc) - np.exp(test_data))/np.abs(np.exp(test_data)))
print('MAPE: {:.2f}%'.format(mape*100))
# Out:
# MSE:  0.0007165236792956891
# MAE:  0.020328620063834665
# RMSE:  0.026767959938995896
# MAPE: 1.97%

# %% [markdown]
# # STEP 6 : ARIMA 모델 훈련과 테스트 3
#
# ## (p, d, q) = 1, 1, 0
#
# ![image-2.png](attachment:image-2.png)

# %%
# Build Model
model = ARIMA(train_data, order=(1, 1, 0)) 
fitted_m = model.fit() 

print(fitted_m.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  close   No. Observations:                  868
# Model:                 ARIMA(1, 1, 0)   Log Likelihood                2241.175
# Date:                Wed, 16 Feb 2022   AIC                          -4478.349
# Time:                        08:03:21   BIC                          -4468.819
# Sample:                             0   HQIC                         -4474.702
#                                 - 868
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0499      0.031     -1.625      0.104      -0.110       0.010
# sigma2         0.0003   1.19e-05     27.943      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               102.46
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.12   Skew:                             0.25
# Prob(H) (two-sided):                  0.35   Kurtosis:                         4.61
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
fitted_m = fitted_m.predict()
fitted_m = fitted_m.drop(fitted_m.index[0])
plt.plot(fitted_m, label='predict')
plt.plot(train_data, label='train_data')
plt.legend()

# %%
model = ARIMA(train_data, order=(1, 1, 0))  # 1.65
fitted_m = model.fit() 
# Forecast : 결과가 fc에 담깁니다. 

fc = fitted_m.forecast(len(test_data), alpha=0.05)  # 95% conf
fc = np.array(fc)
# Make as pandas series
fc_series = pd.Series(fc, index=test_data.index)   # 예측결과

# Plot
plt.figure(figsize=(10,5), dpi=100)
plt.plot(train_data, label='training')
plt.plot(test_data, c='b', label='actual price')
plt.plot(fc_series, c='r',label='predicted price')
plt.legend()
plt.show()

# %%
mse = mean_squared_error(np.exp(test_data), np.exp(fc))
print('MSE: ', mse)

mae = mean_absolute_error(np.exp(test_data), np.exp(fc))
print('MAE: ', mae)

rmse = math.sqrt(mean_squared_error(np.exp(test_data), np.exp(fc)))
print('RMSE: ', rmse)

mape = np.mean(np.abs(np.exp(fc) - np.exp(test_data))/np.abs(np.exp(test_data)))
print('MAPE: {:.2f}%'.format(mape*100))
# Out:
# MSE:  0.0005096200693144251
# MAE:  0.016884098356988182
# RMSE:  0.02257476620730379
# MAPE: 1.65%

# %% [markdown]
# ## 정리
#
# p, q의 값은 p + q < 2, p * q = 0인 값을 많이 쓴다는데, 이렇게 주어야 확실히 결과값이 잘 나오는 것 같다.

# %% [markdown]
# # 기억하고 싶은 것
#
# - warning 뜨는 것 무시
# 아래 코드를 사용하면 warning이 뜨는것을 무시할 수 있다.

# %%
import warnings
warnings.filterwarnings('ignore') #경고 무시

# %% [markdown]
# # 추후에 더 하고싶은 것
#
# 1. 여기선 close 종가만을 가지고 예측을 했는데, 같은 타임 step에서의 거래량이나 pbr, per을 가진 dataframe을 이용해서 모수를 찾고 모델을 학습시켜보고싶습니다.
